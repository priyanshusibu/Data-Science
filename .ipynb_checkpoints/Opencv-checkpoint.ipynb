# %%
print("Hello")
# Out:
# Hello

# %%
pip install opencv.python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv.python in c:\users\priya\appdata\roaming\python\python311\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\datascience\lib\site-packages (from opencv.python) (1.24.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
image=cv2.imread("image/flower.jpg")

# %%
image
# Out:
# array([[[11, 30, 15],
#         [11, 30, 15],
#         [ 9, 28, 13],
#         ...,
#         [24, 32, 21],
#         [24, 33, 20],
#         [24, 33, 20]],
#
#        [[12, 31, 16],
#         [11, 30, 15],
#         [10, 29, 14],
#         ...,
#         [24, 32, 21],
#         [24, 33, 20],
#         [24, 33, 20]],
#
#        [[13, 32, 17],
#         [12, 31, 16],
#         [11, 30, 15],
#         ...,
#         [23, 31, 20],
#         [23, 32, 19],
#         [23, 32, 19]],
#
#        ...,
#
#        [[55, 47, 17],
#         [55, 48, 15],
#         [55, 48, 15],
#         ...,
#         [ 1, 24, 16],
#         [ 1, 24, 16],
#         [ 1, 24, 16]],
#
#        [[56, 48, 18],
#         [56, 49, 16],
#         [57, 50, 17],
#         ...,
#         [ 1, 24, 16],
#         [ 1, 24, 16],
#         [ 1, 24, 16]],
#
#        [[58, 50, 20],
#         [58, 51, 18],
#         [58, 51, 18],
#         ...,
#         [ 1, 24, 16],
#         [ 1, 24, 16],
#         [ 1, 24, 16]]], dtype=uint8)

# %%
image.shape
#It will give a 3D-tensor of 300 row of pixels ,800 cols of pixel and 3 jargor
#images are normally is in tensor
# Out:
# (148, 195, 3)

# %%
image[0]
# Out:
# array([[11, 30, 15],
#        [11, 30, 15],
#        [ 9, 28, 13],
#        [ 7, 26, 11],
#        [ 7, 24, 10],
#        [ 5, 22,  8],
#        [ 3, 20,  6],
#        [ 3, 20,  6],
#        [ 3, 18,  4],
#        [ 2, 17,  3],
#        [ 2, 15,  1],
#        [ 0, 13,  0],
#        [ 0, 11,  0],
#        [ 0, 10,  0],
#        [ 0, 10,  0],
#        [ 0,  9,  0],
#        [ 9, 18,  5],
#        [14, 21,  8],
#        [17, 24, 11],
#        [19, 26, 13],
#        [19, 26, 13],
#        [19, 26, 13],
#        [21, 28, 15],
#        [23, 30, 17],
#        [20, 27, 14],
#        [20, 27, 14],
#        [19, 26, 13],
#        [18, 25, 12],
#        [17, 24, 11],
#        [17, 24, 11],
#        [16, 23, 10],
#        [14, 23, 10],
#        [14, 23, 10],
#        [13, 23, 10],
#        [13, 23, 10],
#        [13, 23, 10],
#        [15, 25,  9],
#        [15, 25,  9],
#        [16, 26, 10],
#        [16, 26, 10],
#        [22, 30, 13],
#        [22, 30, 13],
#        [25, 31, 14],
#        [26, 32, 15],
#        [27, 33, 14],
#        [28, 34, 15],
#        [29, 35, 16],
#        [32, 37, 16],
#        [34, 36, 16],
#        [36, 38, 16],
#        [37, 39, 17],
#        [39, 41, 19],
#        [41, 44, 19],
#        [42, 45, 20],
#        [43, 48, 21],
#        [43, 48, 21],
#        [44, 51, 24],
#        [45, 52, 25],
#        [46, 54, 24],
#        [47, 55, 25],
#        [47, 57, 27],
#        [49, 59, 29],
#        [50, 61, 29],
#        [52, 60, 29],
#        [59, 62, 30],
#        [62, 63, 31],
#        [64, 65, 33],
#        [67, 68, 36],
#        [70, 69, 35],
#        [71, 70, 36],
#        [73, 71, 36],
#        [73, 71, 36],
#        [78, 72, 37],
#        [78, 72, 37],
#        [81, 73, 36],
#        [83, 75, 38],
#        [85, 76, 39],
#        [86, 77, 40],
#        [87, 78, 40],
#        [88, 80, 40],
#        [93, 81, 39],
#        [94, 83, 39],
#        [94, 83, 39],
#        [93, 82, 38],
#        [90, 81, 37],
#        [89, 80, 36],
#        [85, 79, 34],
#        [84, 78, 33],
#        [81, 76, 31],
#        [80, 75, 30],
#        [78, 75, 30],
#        [77, 74, 29],
#        [74, 74, 28],
#        [73, 73, 27],
#        [73, 73, 27],
#        [73, 72, 28],
#        [68, 69, 27],
#        [67, 67, 27],
#        [66, 67, 27],
#        [65, 66, 26],
#        [64, 66, 24],
#        [63, 65, 23],
#        [61, 66, 21],
#        [59, 66, 21],
#        [56, 64, 17],
#        [54, 64, 17],
#        [52, 64, 14],
#        [51, 63, 13],
#        [48, 64, 11],
#        [48, 64, 11],
#        [47, 63, 10],
#        [50, 61, 11],
#        [56, 59, 13],
#        [57, 58, 16],
#        [57, 57, 17],
#        [57, 57, 21],
#        [55, 56, 22],
#        [55, 55, 25],
#        [54, 56, 27],
#        [54, 55, 29],
#        [56, 55, 29],
#        [56, 55, 27],
#        [59, 56, 28],
#        [61, 58, 27],
#        [64, 60, 25],
#        [66, 61, 22],
#        [69, 63, 22],
#        [69, 62, 23],
#        [73, 63, 33],
#        [73, 62, 35],
#        [75, 61, 39],
#        [76, 61, 42],
#        [77, 61, 44],
#        [77, 61, 45],
#        [80, 61, 46],
#        [80, 62, 45],
#        [82, 64, 47],
#        [82, 66, 43],
#        [84, 67, 40],
#        [85, 71, 35],
#        [87, 72, 33],
#        [87, 74, 28],
#        [88, 77, 27],
#        [88, 77, 25],
#        [86, 78, 25],
#        [86, 78, 25],
#        [85, 76, 26],
#        [84, 75, 25],
#        [83, 73, 25],
#        [83, 73, 25],
#        [80, 71, 27],
#        [80, 71, 27],
#        [76, 68, 28],
#        [76, 68, 28],
#        [75, 66, 28],
#        [74, 65, 27],
#        [71, 62, 28],
#        [70, 61, 27],
#        [69, 60, 26],
#        [69, 60, 27],
#        [69, 58, 28],
#        [68, 57, 29],
#        [67, 56, 28],
#        [62, 56, 27],
#        [59, 55, 26],
#        [55, 55, 25],
#        [54, 54, 24],
#        [52, 54, 24],
#        [52, 54, 24],
#        [52, 54, 24],
#        [56, 54, 24],
#        [58, 54, 25],
#        [60, 54, 25],
#        [62, 54, 25],
#        [66, 54, 26],
#        [66, 53, 27],
#        [68, 55, 33],
#        [64, 53, 33],
#        [61, 49, 31],
#        [53, 46, 27],
#        [47, 43, 25],
#        [40, 40, 22],
#        [38, 39, 23],
#        [33, 39, 22],
#        [26, 33, 18],
#        [24, 34, 18],
#        [23, 33, 20],
#        [23, 33, 20],
#        [23, 33, 21],
#        [23, 33, 21],
#        [23, 32, 22],
#        [23, 33, 21],
#        [24, 32, 21],
#        [24, 33, 20],
#        [24, 33, 20]], dtype=uint8)

# %%
image[0][0]
#It will n=
# Out:
# array([11, 30, 15], dtype=uint8)

# %%
//cv2.imshow('',image)
#It will crete an error but we can handel it by following
# Out:
#   Cell In[16], line 1
#     //cv2.imshow('',image)
#     ^
# SyntaxError: invalid syntax

# %%
cv2.imshow('img',image) #Basically create the window and put the image in
cv2.waitKey(0) #Wait for the input like close button or minimize button like that
# Out:
# -1

# %%
20
# Out:
# 20

# %%
cv2.destroyAllWindows() #Once everything is done then distory all the window

# %%
#Once these basic step complet we can start the matplotlib

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(image)
# This is how we can load image using the matplotlib
