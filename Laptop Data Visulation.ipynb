# %%
import pandas as pd  
import matplotlib.pyplot as plt  
  
# reading the csv data set  
dataset = pd.read_csv("best_buy_laptops_2024.csv")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489 entries, 0 to 488
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   brand                        489 non-null    object
#  1   model                        488 non-null    object
#  2   aggregateRating/ratingValue  357 non-null    float64
#  3   aggregateRating/reviewCount  357 non-null    float64
#  4   offers/price                 262 non-null    float64
#  5   offers/priceCurrency         489 non-null    object
#  6   depth                        431 non-null    float64
#  7   width                        431 non-null    float64
#  8   features/0/description       486 non-null    object
#  9   features/1/description       483 non-null    object
# dtypes: float64(5), object(5)
# memory usage: 38.3+ KB

# %%
l= [i+i for i in range(len("bvifevfe"))]
l
# Out:
# [0, 2, 4, 6, 8, 10, 12, 14]

# %%
dataset.head(10)
# Out:
#        brand              model  aggregateRating/ratingValue  \
# 0       Dell  i7430-7374SLV-PUS                          4.7
# 1       Dell  i3520-5810BLK-PUS                          4.6
# 2     Lenovo         82YL0002US                          4.7
# 3  Microsoft          DTI-00001                          4.7
# 4  Microsoft          R1S-00062                          4.7
# 5       Dell  i7630-7312SLV-PUS                          4.7
# 6     Lenovo         82R400DTUS                          4.7
# 7     Lenovo         82YL0005US                          4.8
# 8    Samsung     NP750QFG-KA1US                          4.8
# 9       ASUS   Q410VA-EVO.I5512                          4.7
#
#    aggregateRating/reviewCount  offers/price offers/priceCurrency  depth  \
# 0                       1088.0           NaN                  USD   8.92
# 1                        839.0           NaN                  USD   9.27
# ...

# %%
dataset.head()
# Out:
#        brand              model  aggregateRating/ratingValue  \
# 0       Dell  i7430-7374SLV-PUS                          4.7
# 1       Dell  i3520-5810BLK-PUS                          4.6
# 2     Lenovo         82YL0002US                          4.7
# 3  Microsoft          DTI-00001                          4.7
# 4  Microsoft          R1S-00062                          4.7
#
#    aggregateRating/reviewCount  offers/price offers/priceCurrency  depth  \
# 0                       1088.0           NaN                  USD   8.92
# 1                        839.0           NaN                  USD   9.27
# 2                        127.0           NaN                  USD   8.76
# 3                        926.0           NaN                  USD   7.90
# 4                        422.0           NaN                  USD   8.80
#
#    width                             features/0/description  \
# 0  12.36  Windows 11 brings back the Start Menu from Win...
# ...

# %%
dataset
# Out:
#          brand              model  aggregateRating/ratingValue  \
# 0         Dell  i7430-7374SLV-PUS                          4.7
# 1         Dell  i3520-5810BLK-PUS                          4.6
# 2       Lenovo         82YL0002US                          4.7
# 3    Microsoft          DTI-00001                          4.7
# 4    Microsoft          R1S-00062                          4.7
# ..         ...                ...                          ...
# 484       Dell               5490                          5.0
# 485     Lenovo         21EX0008US                          5.0
# 486     Lenovo         21HF000CUS                          5.0
# 487     Lenovo         21EX0003US                          NaN
# 488       Dell              P7N66                          NaN
#
#      aggregateRating/reviewCount  offers/price offers/priceCurrency  depth  \
# 0                         1088.0           NaN                  USD   8.92
# ...

# %%
ds=dataset

# %%
ds
# Out:
#          brand              model  aggregateRating/ratingValue  \
# 0         Dell  i7430-7374SLV-PUS                          4.7
# 1         Dell  i3520-5810BLK-PUS                          4.6
# 2       Lenovo         82YL0002US                          4.7
# 3    Microsoft          DTI-00001                          4.7
# 4    Microsoft          R1S-00062                          4.7
# ..         ...                ...                          ...
# 484       Dell               5490                          5.0
# 485     Lenovo         21EX0008US                          5.0
# 486     Lenovo         21HF000CUS                          5.0
# 487     Lenovo         21EX0003US                          NaN
# 488       Dell              P7N66                          NaN
#
#      aggregateRating/reviewCount  offers/price offers/priceCurrency  depth  \
# 0                         1088.0           NaN                  USD   8.92
# ...

# %%
ds.head(25)
# Out:
#         brand                model  aggregateRating/ratingValue  \
# 0        Dell    i7430-7374SLV-PUS                          4.7
# 1        Dell    i3520-5810BLK-PUS                          4.6
# 2      Lenovo           82YL0002US                          4.7
# 3   Microsoft            DTI-00001                          4.7
# 4   Microsoft            R1S-00062                          4.7
# 5        Dell    i7630-7312SLV-PUS                          4.7
# 6      Lenovo           82R400DTUS                          4.7
# 7      Lenovo           82YL0005US                          4.8
# 8     Samsung       NP750QFG-KA1US                          4.8
# 9        ASUS     Q410VA-EVO.I5512                          4.7
# 10    Samsung       NP750QFG-KA2US                          4.8
# 11         HP          14-es0033dx                          4.7
# 12         HP          15-fh0023dx                          4.7
# 13       Acer        PHN16-71-73LT                          4.6
# ...

# %%
ds.row
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15756\3171576967.py in ?()
# ----> 1 ds.row
#
# C:\DataScience\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'row'

# %%
l1=[1,2,3,4,5,6]
l2=[1,2,3,4,5,6]
l3=zip(l1,l2)

# %%
l3

# %%
print(l3)

# %%
len(l3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 len(l3)
#
# TypeError: object of type 'zip' has no len()

# %%
d={1:"sibu",2:"priyasnk",3:"lilly",4:"Kanha",6:"Payal"}
d
# Out:
# {1: 'sibu', 2: 'priyasnk', 3: 'lilly', 4: 'Kanha', 6: 'Payal'}

# %%
d.Series()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 d.Series()
#
# AttributeError: 'dict' object has no attribute 'Series'

# %%
pd=Series(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 pd=Series(d)
#
# NameError: name 'Series' is not defined

# %%
pd.Series(d)
# Out:
# 1        sibu
# 2    priyasnk
# 3       lilly
# 4       Kanha
# 6       Payal
# dtype: object

# %%
ds.index
# Out:
# RangeIndex(start=0, stop=489, step=1)

# %%
ds.columns
# Out:
# Index(['brand', 'model', 'aggregateRating/ratingValue',
#        'aggregateRating/reviewCount', 'offers/price', 'offers/priceCurrency',
#        'depth', 'width', 'features/0/description', 'features/1/description'],
#       dtype='object')

# %%
ds['brand']
# Out:
# 0           Dell
# 1           Dell
# 2         Lenovo
# 3      Microsoft
# 4      Microsoft
#          ...
# 484         Dell
# 485       Lenovo
# 486       Lenovo
# 487       Lenovo
# 488         Dell
# Name: brand, Length: 489, dtype: object

# %%
ds.dtypes
# Out:
# brand                           object
# model                           object
# aggregateRating/ratingValue    float64
# aggregateRating/reviewCount    float64
# offers/price                   float64
# offers/priceCurrency            object
# depth                          float64
# width                          float64
# features/0/description          object
# features/1/description          object
# dtype: object

# %%
ds.describe()
# Out:
#        aggregateRating/ratingValue  aggregateRating/reviewCount  offers/price  \
# count                   357.000000                   357.000000    262.000000
# mean                      4.413445                   254.708683   1159.040687
# std                       0.641880                   607.260976    782.605079
# min                       1.000000                     1.000000    143.990000
# 25%                       4.200000                     3.000000    639.990000
# 50%                       4.600000                    18.000000    959.990000
# 75%                       4.800000                   208.000000   1494.990000
# max                       5.000000                  4231.000000   4489.990000
#
#             depth       width
# count  431.000000  431.000000
# mean     9.678770   11.927030
# std      2.911987    3.333199
# min      0.490000    0.580000
# 25%      8.655000   11.300000
# 50%      9.220000   12.510000
# 75%     10.400000   14.050000
# ...

# %%
ds.T
# Out:
#                                                                            0    \
# brand                                                                     Dell
# model                                                        i7430-7374SLV-PUS
# aggregateRating/ratingValue                                                4.7
# aggregateRating/reviewCount                                             1088.0
# offers/price                                                               NaN
# offers/priceCurrency                                                       USD
# depth                                                                     8.92
# width                                                                    12.36
# features/0/description       Windows 11 brings back the Start Menu from Win...
# features/1/description       Equipped with a FHD+ IPS touch screen, the bor...
#
#                                                                            1    \
# ...

# %%
ds.T
# Out:
#                                                                            0    \
# brand                                                                     Dell
# model                                                        i7430-7374SLV-PUS
# aggregateRating/ratingValue                                                4.7
# aggregateRating/reviewCount                                             1088.0
# offers/price                                                               NaN
# offers/priceCurrency                                                       USD
# depth                                                                     8.92
# width                                                                    12.36
# features/0/description       Windows 11 brings back the Start Menu from Win...
# features/1/description       Equipped with a FHD+ IPS touch screen, the bor...
#
#                                                                            1    \
# ...

# %%
ds
# Out:
#          brand              model  aggregateRating/ratingValue  \
# 0         Dell  i7430-7374SLV-PUS                          4.7
# 1         Dell  i3520-5810BLK-PUS                          4.6
# 2       Lenovo         82YL0002US                          4.7
# 3    Microsoft          DTI-00001                          4.7
# 4    Microsoft          R1S-00062                          4.7
# ..         ...                ...                          ...
# 484       Dell               5490                          5.0
# 485     Lenovo         21EX0008US                          5.0
# 486     Lenovo         21HF000CUS                          5.0
# 487     Lenovo         21EX0003US                          NaN
# 488       Dell              P7N66                          NaN
#
#      aggregateRating/reviewCount  offers/price offers/priceCurrency  depth  \
# 0                         1088.0           NaN                  USD   8.92
# ...

# %%
ds[0:4]
# Out:
#        brand              model  aggregateRating/ratingValue  \
# 0       Dell  i7430-7374SLV-PUS                          4.7
# 1       Dell  i3520-5810BLK-PUS                          4.6
# 2     Lenovo         82YL0002US                          4.7
# 3  Microsoft          DTI-00001                          4.7
#
#    aggregateRating/reviewCount  offers/price offers/priceCurrency  depth  \
# 0                       1088.0           NaN                  USD   8.92
# 1                        839.0           NaN                  USD   9.27
# 2                        127.0           NaN                  USD   8.76
# 3                        926.0           NaN                  USD   7.90
#
#    width                             features/0/description  \
# 0  12.36  Windows 11 brings back the Start Menu from Win...
# 1  14.11  Experience the most secure Windows ever built ...
# 2  12.51  Windows 11 brings back the Start Menu from Win...
# ...

# %%
ds[ds["aggregateRating/ratingValue"] >= 5]
# Out:
#          brand               model  aggregateRating/ratingValue  \
# 53      Lenovo          82LM00UEUS                          5.0
# 60        ASUS        F1605VA-DS74                          5.0
# 63          HP         14-eu0023dx                          5.0
# 89       Razer  RZ09-05102EJ9-R3U1                          5.0
# 94          LG    14Z90RS-K.AAW7U1                          5.0
# ..         ...                 ...                          ...
# 470  Microsoft      GSRF 5PB-00001                          5.0
# 471       Dell               2H58M                          5.0
# 484       Dell                5490                          5.0
# 485     Lenovo          21EX0008US                          5.0
# 486     Lenovo          21HF000CUS                          5.0
#
#      aggregateRating/reviewCount  offers/price offers/priceCurrency  depth  \
# 53                           2.0        339.99                  USD   8.33
# ...

# %%
ds.loc[brand[0]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 ds.loc[brand[0]]
#
# NameError: name 'brand' is not defined

# %%
ds.iloc[3]
# Out:
# brand                                                                  Microsoft
# model                                                                  DTI-00001
# aggregateRating/ratingValue                                                  4.7
# aggregateRating/reviewCount                                                926.0
# offers/price                                                                 NaN
# offers/priceCurrency                                                         USD
# depth                                                                        7.9
# width                                                                       11.5
# features/0/description         Find the relevant information and ideas you ne...
# features/1/description         Iconic 2-in-1 design transforms into what you ...
# Name: 3, dtype: object

# %%
ds[3:4]
# Out:
#        brand      model  aggregateRating/ratingValue  \
# 3  Microsoft  DTI-00001                          4.7
#
#    aggregateRating/reviewCount  offers/price offers/priceCurrency  depth  \
# 3                        926.0           NaN                  USD    7.9
#
#    width                             features/0/description  \
# 3   11.5  Find the relevant information and ideas you ne...
#
#                               features/1/description
# 3  Iconic 2-in-1 design transforms into what you ...

# %%
ds.iloc[3:5, 0:2]
# Out:
#        brand      model
# 3  Microsoft  DTI-00001
# 4  Microsoft  R1S-00062

# %%
ds.iloc[[1, 2, 4], [0, 5]]
# Out:
#        brand offers/priceCurrency
# 1       Dell                  USD
# 2     Lenovo                  USD
# 4  Microsoft                  USD

# %%
ds.iloc[1, 1]
# Out:
# 'i3520-5810BLK-PUS'

# %%
ds
# Out:
#          brand              model  aggregateRating/ratingValue  \
# 0         Dell  i7430-7374SLV-PUS                          4.7
# 1         Dell  i3520-5810BLK-PUS                          4.6
# 2       Lenovo         82YL0002US                          4.7
# 3    Microsoft          DTI-00001                          4.7
# 4    Microsoft          R1S-00062                          4.7
# ..         ...                ...                          ...
# 484       Dell               5490                          5.0
# 485     Lenovo         21EX0008US                          5.0
# 486     Lenovo         21HF000CUS                          5.0
# 487     Lenovo         21EX0003US                          NaN
# 488       Dell              P7N66                          NaN
#
#      aggregateRating/reviewCount  offers/price offers/priceCurrency  depth  \
# 0                         1088.0           NaN                  USD   8.92
# ...

# %%
ds.shape
# Out:
# (489, 10)

# %%
ds.min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 ds.min()
#
# File C:\DataScience\Lib\site-packages\pandas\core\generic.py:11669, in NDFrame._add_numeric_operations.<locals>.min(self, axis, skipna, numeric_only, **kwargs)
#   11650 @doc(
#   11651     _num_doc,
#   11652     desc="Return the minimum of the values over the requested axis.\n\n"
#    (...)
#   11667     **kwargs,
#   11668 ):
# > 11669     return NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#
# File C:\DataScience\Lib\site-packages\pandas\core\generic.py:11169, in NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   11162 def min(
#   11163     self,
#   11164     axis: Axis | None = 0,
#    (...)
#   11167     **kwargs,
#   11168 ):
# > 11169     return self._stat_function(
#   11170         "min",
#   11171         nanops.nanmin,
#   11172         axis,
# ...

# %%
ds.max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 ds.max()
#
# File C:\DataScience\Lib\site-packages\pandas\core\generic.py:11646, in NDFrame._add_numeric_operations.<locals>.max(self, axis, skipna, numeric_only, **kwargs)
#   11627 @doc(
#   11628     _num_doc,
#   11629     desc="Return the maximum of the values over the requested axis.\n\n"
#    (...)
#   11644     **kwargs,
#   11645 ):
# > 11646     return NDFrame.max(self, axis, skipna, numeric_only, **kwargs)
#
# File C:\DataScience\Lib\site-packages\pandas\core\generic.py:11185, in NDFrame.max(self, axis, skipna, numeric_only, **kwargs)
#   11178 def max(
#   11179     self,
#   11180     axis: Axis | None = 0,
#    (...)
#   11183     **kwargs,
#   11184 ):
# > 11185     return self._stat_function(
#   11186         "max",
#   11187         nanops.nanmax,
#   11188         axis,
# ...

# %%
ds.describe()
# Out:
#        aggregateRating/ratingValue  aggregateRating/reviewCount  offers/price  \
# count                   357.000000                   357.000000    262.000000
# mean                      4.413445                   254.708683   1159.040687
# std                       0.641880                   607.260976    782.605079
# min                       1.000000                     1.000000    143.990000
# 25%                       4.200000                     3.000000    639.990000
# 50%                       4.600000                    18.000000    959.990000
# 75%                       4.800000                   208.000000   1494.990000
# max                       5.000000                  4231.000000   4489.990000
#
#             depth       width
# count  431.000000  431.000000
# mean     9.678770   11.927030
# std      2.911987    3.333199
# min      0.490000    0.580000
# 25%      8.655000   11.300000
# 50%      9.220000   12.510000
# 75%     10.400000   14.050000
# ...

# %%
ds.index
# Out:
# RangeIndex(start=0, stop=489, step=1)

# %%
ds.count()
# Out:
# brand                          489
# model                          488
# aggregateRating/ratingValue    357
# aggregateRating/reviewCount    357
# offers/price                   262
# offers/priceCurrency           489
# depth                          431
# width                          431
# features/0/description         486
# features/1/description         483
# dtype: int64

# %%
from matplotlib import pyplot as plt

# %%
plt.title("My Ist")
plt.plot(depth,aggregateRating/ratingValue, color='green', marker='o', linestyle='solid')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 2
#       1 plt.title("My Ist")
# ----> 2 plt.plot(depth,aggregateRating/ratingValue, color='green', marker='o', linestyle='solid')
#       3 plt.show()
#
# NameError: name 'depth' is not defined
