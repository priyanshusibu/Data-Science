# %%
from matplotlib import pyplot as plt
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]
# create a line chart, years on x-axis, gdp on y-axis
plt.plot(years, gdp, color='green', marker='o', linestyle='solid')
# add a title
plt.title("Nominal GDP")
# add a label to the y-axis
plt.ylabel("Billions of $")
plt.xlabel("Year")
plt.show()

# %%
movies = ["Annie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"]
num_oscars = [5, 11, 3, 8, 10]
# plot bars with left x-coordinates [0, 1, 2, 3, 4], heights [num_oscars]
plt.bar(range(len(movies)), num_oscars)
plt.title("My Favorite Movies") # add a title
plt.ylabel("# of Academy Awards") # label the y-axis
# label x-axis with movie names at bar centers
plt.xticks(range(len(movies)), movies)
plt.show()

# %%
variance = [1, 2, 4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
total_error = [x + y for x, y in zip(variance, bias_squared)]
xs = [i for i, _ in enumerate(variance)]
# We can make multiple calls to plt.plot
# to show multiple series on the same chart
plt.plot(xs, variance, 'g-', label='variance') # green solid line
plt.plot(xs, bias_squared, 'r-.', label='bias^2') # red dot-dashed line
plt.plot(xs, total_error, 'b:', label='total error') # blue dotted line
# Because we've assigned labels to each series,
# we can get a legend for free (loc=9 means "top center")
plt.legend(loc=9)
plt.xlabel("model complexity")
plt.xticks([])
plt.title("The Bias-Variance Tradeoff")
plt.show()

# %%
variance = [1, 2, 4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1,5678]
t_zip=zip(variance,bias_squared)

# %%
t_zip

# %%
print(t_zip)

# %%
l=[i+j for i,j in t_zip]
l
# Out:
# [257, 130, 68, 40, 32, 40, 68, 130, 257]

# %%
import panda as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 import panda as pd
#
# ModuleNotFoundError: No module named 'panda'

# %%
import pandas as pd  
import matplotlib.pyplot as plt  
# reading the csv data set  
dataset = pd.read_csv("data.csv")

# %%
datset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 datset
#
# NameError: name 'datset' is not defined

# %%
dataset
# Out:
#       Country Name Country Code  year  \
# 0      Afghanistan          AFG  1960
# 1      Afghanistan          AFG  1961
# 2      Afghanistan          AFG  1962
# 3      Afghanistan          AFG  1963
# 4      Afghanistan          AFG  1964
# ...            ...          ...   ...
# 16099     Zimbabwe          ZWE  2016
# 16100     Zimbabwe          ZWE  2017
# 16101     Zimbabwe          ZWE  2018
# 16102     Zimbabwe          ZWE  2019
# 16103     Zimbabwe          ZWE  2020
#
#        Access to electricity (% of population)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 16099                                39.923992
# 16100                                40.482048
# 16101                                41.041584
# ...

# %%
dataset.columns
# Out:
# Index(['Country Name', 'Country Code', 'year',
#        'Access to electricity (% of population)',
#        'Access to electricity, rural (% of rural population)',
#        'Agricultural irrigated land (% of total agricultural land)',
#        'Agricultural land (% of land area)', 'Agricultural land (sq. km)',
#        'Agricultural machinery, tractors',
#        'Agricultural machinery, tractors per 100 sq. km of arable land',
#        'Agricultural methane emissions (% of total)',
#        'Agricultural methane emissions (thousand metric tons of CO2 equivalent)',
#        'Agricultural nitrous oxide emissions (% of total)',
#        'Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)',
#        'Agricultural raw materials exports (% of merchandise exports)',
#        'Agricultural raw materials imports (% of merchandise imports)',
#        'Agriculture, forestry, and fishing, value added (% of GDP)',
# ...

# %%
s="Orissa Literacy Rate
Population
Literates
Literacy
1.	Khordha	
2,251,673
1,749,936
86.88%
2.	Jagatsinghapur	
1,136,971
889,027
86.59%
3.	Cuttack	
2,624,470
2,011,469
85.50%
4.	Kendrapara	
1,440,361
1,089,265
85.15%
5.	Puri
1,698,730
1,291,939
84.67%
6.	Bhadrak	
1,506,337
1,094,140
82.78%
7.	Nayagarh	
962,789
688,362
80.42%
8.	Jajapur	
1,827,192
1,290,455
80.13%
9.	Balasore	
2,320,529
1,621,232
79.79%
10.	Jharsuguda	
579,505
405,879
78.86%
11.	Dhenkanal	
1,192,811
829,910
78.76%
12.	Anugul	
1,273,821
869,456
77.53%
13.	Sambalpur	
1,041,099
703,691
76.22%
14.	Bargarh	
1,481,255
983,783
74.62%
15.	Subarnapur	
610,183
398,421
74.42%
16.	Sundargarh	
2,093,437
1,342,322
73.34%
17.	Debagarh	
312,520
197,819
72.57%
18.	Baudh	
441,162
271,612
71.61%
19.	Ganjam	
3,529,031
2,210,050
71.09%
20.	Kendujhar	
1,801,733
1,052,518
68.24%
21.	Balangir	
1,648,997
927,260
64.72%
22.	Kandhamal	
733,110
399,786
64.13%
23.	Mayurbhanj	
2,519,738
1,369,397
63.17%
24.	Kalahandi	
1,576,869
802,036
59.22%
25.	Nuapada	
610,382
299,383
57.35%
26.	Gajapati	
577,817
262,537
53.49%
27.	Rayagada	
967,911
407,735
49.76%
28.	Koraput	
1,379,647
568,090
49.21%
29.	Malkangiri	
613,192
244,706
48.54%
30.	Nabarangapur	
1,220,946
470,379
46.43%"
# Out:
#   Cell In[2], line 1
#     s="Orissa Literacy Rate
#       ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
1	Ganjam	Blocks	3,529,031	71.09%	983
2	Cuttack	Blocks	2,624,470	85.5%	940
3	Mayurbhanj	Blocks	2,519,738	63.17%	1,006
4	Baleshwar	Blocks	2,320,529	79.79%	957
5	Khordha	Blocks	2,251,673	86.88%	929
6	Sundargarh	Blocks	2,093,437	73.34%	973
7	Jajapur	Blocks	1,827,192	80.13%	973
8	Kendujhar	Blocks	1,801,733	68.24%	988
9	Puri	Blocks	1,698,730	84.67%	963
10	Balangir	Blocks	1,648,997	64.72%	987
11	KalahandiBlocks	1,576,869	59.22%	1,003
12	Bhadrak	Blocks	1,506,337	82.78%	981
13	Bargarh	Blocks	1,481,255	74.62%	977
14	Kendrapara	Blocks	1,440,361	85.15%	1,007
15	Koraput	Blocks	1,379,647	49.21%	1,032
16	Anugul	Blocks	1,273,821	77.53%	943
17	Nabarangapur	Blocks	1,220,946	46.43%	1,019
18	Dhenkanal	Blocks	1,192,811	78.76%	947
19	Jagatsinghapur	Blocks	1,136,971	86.59%	968
20	Sambalpur	Blocks	1,041,099	76.22%	976
21	Rayagada	Blocks	967,911	49.76%	1,051
22	Nayagarh	Blocks	962,789	80.42%	915
23	Kandhamal	Blocks	733,110	64.13%	1,037
24	Malkangiri	Blocks	613,192 48.54%	1,020
25	Nuapada	Blocks	610,382	57.35%	1,021
26	Subarnapur	Blocks	610,183	74.42%	960
27	Jharsuguda	Blocks	579,505	78.86%	953
28	Gajapati	Blocks	577,817	53.49%	1,043
29	Baudh	Blocks	441,162	71.61%	991
30	Debagarh	Blocks	312,520	72.57%	975

# %%
f=open("C:/Users/priya/Data Science Priyanshu/Litracy.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 f=open("C:/Users/priya/Data Science Priyanshu/Litracy.txt")
#
# File C:\DataScience\Lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/priya/Data Science Priyanshu/Litracy.txt'

# %%
f=open("Literacy.txt","r")

# %%
f
# Out:
# <_io.TextIOWrapper name='Literacy.txt' mode='r' encoding='cp1252'>

# %%
f.read()
# Out:
# ''

# %%
f.readline()
# Out:
# ''

# %%
f.readlines()
# Out:
# []

# %%
l1=f.readlines()

# %%
l1
# Out:
# []

# %%
print(f.read(5))

# %%
f.readline()
# Out:
# ''

# %%
f.read()
# Out:
# ''

# %%
print(f.read())

# %%
f3=open("Literacy.txt","r")

# %%
f3.readline()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 f3.readline()
#
# NameError: name 'f3' is not defined

# %%
f2.read()
# Out:
# ''

# %%
f3=open("Literacy.txt","r")

# %%
f3.readline()
# Out:
# '1\tGanjam\tBlocks\t3,529,031\t71.09%\t983\n'

# %%
f3.readline()
# Out:
# '2\tCuttack\tBlocks\t2,624,470\t85.5%\t940\n'

# %%
s=f3.readline()
strings=s.split("\t")

# %%
strings
# Out:
# ['3', 'Mayurbhanj', 'Blocks', '2,519,738', '63.17%', '1,006\n']

# %%
f=open("Literacy.txt","r")

# %%
s=f.readline()
strings=s.split("\t")
strings
# Out:
# ['1', 'Ganjam', 'Blocks', '3,529,031', '71.09%', '983\n']

# %%
s=f.readline()
strings=s.split("\t")
strings
# Out:
# ['2', 'Cuttack', 'Blocks', '2,624,470', '85.5%', '940\n']

# %%
lines=f.readlines()
print(lines)
# Out:
# ['3\tMayurbhanj\tBlocks\t2,519,738\t63.17%\t1,006\n', '4\tBaleshwar\tBlocks\t2,320,529\t79.79%\t957\n', '5\tKhordha\tBlocks\t2,251,673\t86.88%\t929\n', '6\tSundargarh\tBlocks\t2,093,437\t73.34%\t973\n', '7\tJajapur\tBlocks\t1,827,192\t80.13%\t973\n', '8\tKendujhar\tBlocks\t1,801,733\t68.24%\t988\n', '9\tPuri\tBlocks\t1,698,730\t84.67%\t963\n', '10\tBalangir\tBlocks\t1,648,997\t64.72%\t987\n', '11\tKalahandiBlocks\t1,576,869\t59.22%\t1,003\n', '12\tBhadrak\tBlocks\t1,506,337\t82.78%\t981\n', '13\tBargarh\tBlocks\t1,481,255\t74.62%\t977\n', '14\tKendrapara\tBlocks\t1,440,361\t85.15%\t1,007\n', '15\tKoraput\tBlocks\t1,379,647\t49.21%\t1,032\n', '16\tAnugul\tBlocks\t1,273,821\t77.53%\t943\n', '17\tNabarangapur\tBlocks\t1,220,946\t46.43%\t1,019\n', '18\tDhenkanal\tBlocks\t1,192,811\t78.76%\t947\n', '19\tJagatsinghapur\tBlocks\t1,136,971\t86.59%\t968\n', '20\tSambalpur\tBlocks\t1,041,099\t76.22%\t976\n', '21\tRayagada\tBlocks\t967,911\t49.76%\t1,051\n', '22\tNayagarh\tBlocks\t962,789\t80.4
# ...

# %%
len(lines)
# Out:
# 28

# %%
f=open("Literacy.txt","r")
lines=f.readlines()
print(lines)
# Out:
# ['1\tGanjam\tBlocks\t3,529,031\t71.09%\t983\n', '2\tCuttack\tBlocks\t2,624,470\t85.5%\t940\n', '3\tMayurbhanj\tBlocks\t2,519,738\t63.17%\t1,006\n', '4\tBaleshwar\tBlocks\t2,320,529\t79.79%\t957\n', '5\tKhordha\tBlocks\t2,251,673\t86.88%\t929\n', '6\tSundargarh\tBlocks\t2,093,437\t73.34%\t973\n', '7\tJajapur\tBlocks\t1,827,192\t80.13%\t973\n', '8\tKendujhar\tBlocks\t1,801,733\t68.24%\t988\n', '9\tPuri\tBlocks\t1,698,730\t84.67%\t963\n', '10\tBalangir\tBlocks\t1,648,997\t64.72%\t987\n', '11\tKalahandiBlocks\t1,576,869\t59.22%\t1,003\n', '12\tBhadrak\tBlocks\t1,506,337\t82.78%\t981\n', '13\tBargarh\tBlocks\t1,481,255\t74.62%\t977\n', '14\tKendrapara\tBlocks\t1,440,361\t85.15%\t1,007\n', '15\tKoraput\tBlocks\t1,379,647\t49.21%\t1,032\n', '16\tAnugul\tBlocks\t1,273,821\t77.53%\t943\n', '17\tNabarangapur\tBlocks\t1,220,946\t46.43%\t1,019\n', '18\tDhenkanal\tBlocks\t1,192,811\t78.76%\t947\n', '19\tJagatsinghapur\tBlocks\t1,136,971\t86.59%\t968\n', '20\tSambalpur\tBlocks\t1,041,099\t76.22%\t
# ...

# %%
len(lines)
# Out:
# 30

# %%
total=[]
for i in range(len(lines)):
    a=lines[i].split("\t")
    total.append(a)
total
# Out:
# [['1', 'Ganjam', 'Blocks', '3,529,031', '71.09%', '983\n'],
#  ['2', 'Cuttack', 'Blocks', '2,624,470', '85.5%', '940\n'],
#  ['3', 'Mayurbhanj', 'Blocks', '2,519,738', '63.17%', '1,006\n'],
#  ['4', 'Baleshwar', 'Blocks', '2,320,529', '79.79%', '957\n'],
#  ['5', 'Khordha', 'Blocks', '2,251,673', '86.88%', '929\n'],
#  ['6', 'Sundargarh', 'Blocks', '2,093,437', '73.34%', '973\n'],
#  ['7', 'Jajapur', 'Blocks', '1,827,192', '80.13%', '973\n'],
#  ['8', 'Kendujhar', 'Blocks', '1,801,733', '68.24%', '988\n'],
#  ['9', 'Puri', 'Blocks', '1,698,730', '84.67%', '963\n'],
#  ['10', 'Balangir', 'Blocks', '1,648,997', '64.72%', '987\n'],
#  ['11', 'KalahandiBlocks', '1,576,869', '59.22%', '1,003\n'],
#  ['12', 'Bhadrak', 'Blocks', '1,506,337', '82.78%', '981\n'],
#  ['13', 'Bargarh', 'Blocks', '1,481,255', '74.62%', '977\n'],
#  ['14', 'Kendrapara', 'Blocks', '1,440,361', '85.15%', '1,007\n'],
#  ['15', 'Koraput', 'Blocks', '1,379,647', '49.21%', '1,032\n'],
# ...

# %%
total
# Out:
# [['1', 'Ganjam', 'Blocks', '3,529,031', '71.09%', '983\n'],
#  ['2', 'Cuttack', 'Blocks', '2,624,470', '85.5%', '940\n'],
#  ['3', 'Mayurbhanj', 'Blocks', '2,519,738', '63.17%', '1,006\n'],
#  ['4', 'Baleshwar', 'Blocks', '2,320,529', '79.79%', '957\n'],
#  ['5', 'Khordha', 'Blocks', '2,251,673', '86.88%', '929\n'],
#  ['6', 'Sundargarh', 'Blocks', '2,093,437', '73.34%', '973\n'],
#  ['7', 'Jajapur', 'Blocks', '1,827,192', '80.13%', '973\n'],
#  ['8', 'Kendujhar', 'Blocks', '1,801,733', '68.24%', '988\n'],
#  ['9', 'Puri', 'Blocks', '1,698,730', '84.67%', '963\n'],
#  ['10', 'Balangir', 'Blocks', '1,648,997', '64.72%', '987\n'],
#  ['11', 'KalahandiBlocks', '1,576,869', '59.22%', '1,003\n'],
#  ['12', 'Bhadrak', 'Blocks', '1,506,337', '82.78%', '981\n'],
#  ['13', 'Bargarh', 'Blocks', '1,481,255', '74.62%', '977\n'],
#  ['14', 'Kendrapara', 'Blocks', '1,440,361', '85.15%', '1,007\n'],
#  ['15', 'Koraput', 'Blocks', '1,379,647', '49.21%', '1,032\n'],
# ...

# %%
total.insert(0,"XXX")

# %%
total
# Out:
# ['XXX',
#  ['1', 'Ganjam', 'Blocks', '3,529,031', '71.09%', '983\n'],
#  ['2', 'Cuttack', 'Blocks', '2,624,470', '85.5%', '940\n'],
#  ['3', 'Mayurbhanj', 'Blocks', '2,519,738', '63.17%', '1,006\n'],
#  ['4', 'Baleshwar', 'Blocks', '2,320,529', '79.79%', '957\n'],
#  ['5', 'Khordha', 'Blocks', '2,251,673', '86.88%', '929\n'],
#  ['6', 'Sundargarh', 'Blocks', '2,093,437', '73.34%', '973\n'],
#  ['7', 'Jajapur', 'Blocks', '1,827,192', '80.13%', '973\n'],
#  ['8', 'Kendujhar', 'Blocks', '1,801,733', '68.24%', '988\n'],
#  ['9', 'Puri', 'Blocks', '1,698,730', '84.67%', '963\n'],
#  ['10', 'Balangir', 'Blocks', '1,648,997', '64.72%', '987\n'],
#  ['11', 'KalahandiBlocks', '1,576,869', '59.22%', '1,003\n'],
#  ['12', 'Bhadrak', 'Blocks', '1,506,337', '82.78%', '981\n'],
#  ['13', 'Bargarh', 'Blocks', '1,481,255', '74.62%', '977\n'],
#  ['14', 'Kendrapara', 'Blocks', '1,440,361', '85.15%', '1,007\n'],
#  ['15', 'Koraput', 'Blocks', '1,379,647', '49.21%', '1,032\n'],
# ...

# %%
from matplotlib import pyplot as plt
x=[10,20,30,40,50,60,70,50,60]
y=[100,150,200,300,356,400,500,600,700]
plt.plot(x,y)

# %%
#xticks function is uned for giving the values to the ticks
plt.xticks(x,["a","b","c","d","e","f","g"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 #xticks function is uned for giving the values to the ticks
# ----> 2 plt.xticks(x,["a","b","c","d","e","f","g"])
#
# File C:\DataScience\Lib\site-packages\matplotlib\pyplot.py:1893, in xticks(ticks, labels, minor, **kwargs)
#    1891         l._internal_update(kwargs)
#    1892 else:
# -> 1893     labels = ax.set_xticklabels(labels, minor=minor, **kwargs)
#    1895 return locs, labels
#
# File C:\DataScience\Lib\site-packages\matplotlib\axes\_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File C:\DataScience\Lib\site-packages\matplotlib\_api\deprecation.py:297, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     292     warn_deprecated(
# ...

# %%
from matplotlib import pyplot as plt
x=[10,20,30,40,50]
y=[100,150,200,300,356]
#xticks function is uned for giving the values to the ticks
plt.xticks(x,["a","b","c","d","e"])
#as well as we can writes the name in the y-axis as ystics(y-asix name,valuees_of_names)
plt.plot(x,y)
plt.show()
#we can change the limit of the x-axis and y-axis 
#like x-axis starts from 0 t0 100 or y axis starts from 0 to 300
plt.xlim([10,100])
plt.ylim([0,1000])
# Out:
# (0.0, 1000.0)
