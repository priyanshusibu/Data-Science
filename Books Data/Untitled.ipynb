# %%
import pandas as pd

# %%
df=pd.read_csv("books.csv")

# %%
df
# Out:
#           ISBN10        ISBN13  \
# 0      195153448  9.780000e+12
# 1        2005018  9.780000e+12
# 2       60973129  9.780000e+12
# 3      374157065  9.780000e+12
# 4      393045218  9.780000e+12
# ...          ...           ...
# 24995  743224914  9.780000e+12
# 24996  395585643  9.780000e+12
# 24997  800718372  9.780000e+12
# 24998   60081651  9.780000e+12
# 24999  151009376  9.780000e+12
#
#                                                    Title  \
# 0                                    Classical Mythology
# 1                                  Clara Callan: A Novel
# 2                                   Decision In Normandy
# 3      Flu: The Story Of The Great Influenza Pandemic...
# 4                                 The Mummies Of Urumchi
# ...                                                  ...
# 24995                     Christmas In Plains : Memories
# 24996                                 The New Fit Or Fat
# 24997                                      Flabbergasted
# ...

# %%
df.head()
# Out:
#       ISBN10        ISBN13                                              Title  \
# 0  195153448  9.780000e+12                                Classical Mythology
# 1    2005018  9.780000e+12                              Clara Callan: A Novel
# 2   60973129  9.780000e+12                               Decision In Normandy
# 3  374157065  9.780000e+12  Flu: The Story Of The Great Influenza Pandemic...
# 4  393045218  9.780000e+12                             The Mummies Of Urumchi
#
#                                      Author  \
# 0     Mark P. O. Morford,Robert J. Lenardon
# 1                      Richard Bruce Wright
# 2                              Carlo D'Este
# 3                               Gina Kolata
# 4  Elizabeth Wayland Barber,E. J. W. Barber
#
#                                              Cover  \
# 0  http://www.openisbn.com/cover/0195153448_72.jpg
# 1  http://www.openisbn.com/cover/0002005018_72.jpg
# 2  http://www.openisbn.com/cover/0060973129_72.jpg
# ...

# %%
df.iloc
[1,2,3]
# Out:
# [1, 2, 3]
